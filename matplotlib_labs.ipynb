# %% [markdown]
# <a href="https://colab.research.google.com/github/anurg/aicourse/blob/main/matplotlib_labs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.array([10,20,30,40,50])
y=np.array([23,45,34,56,34])
plt.plot(x,y,"--",color="green")
plt.axis([0,70,0,60]) #[xmin,xmax,ymin,ymax]
                     #[xmin to xmax,ymin to ymax]
plt.title("First Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
#draw a line between 2 points (2,7) and (3,8)
plt.plot([2,3],[7,8])
plt.show()

# %%
#Horizontal Line & Vertical line
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[30,30,30,30,30]
plt.plot(x,y,linestyle="dashed",linewidth=4,label="Vertical Line",color="brown")
plt.plot(y,x,linestyle="dotted",linewidth=4,label="Vertical Line",color="green")
plt.show()

# %%
plt.plot([1,2,3],[5,7,4],"p",color="g")

plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
plt.plot(x,marker="o")
# plt.grid()
# plt.grid(axis="x")
plt.grid(axis="y")

plt.show()
# Out:
# /tmp/ipykernel_499/1165186369.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
from langchain_openai import ChatOpenAI
# Initialize OpenAI model
openai_llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.5)
response = openai_llm.invoke("Tell me a joke about light bulbs!")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_openai import ChatOpenAI
#       2 # Initialize OpenAI model
# ----> 3 openai_llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.5)
#       4 response = openai_llm.invoke("Tell me a joke about light bulbs!")
#       5 print(response.content)
#
# File ~/aicourse/venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/aicourse/venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1090, in BaseChatOpenAI.validate_environment(self)
#    1080         self.http_async_client = httpx.AsyncClient(
#    1081             proxy=self.openai_proxy, verify=global_ssl_context
#    1082         )
#    1083     async_specific = {
#    1084         "http_client": self.http_async_client
#    1085         or _get_default_async_httpx_client(
#    (...)
#    1088         "api_key": async_api_key_value,
#    1089     }
# -> 1090     self.root_async_client = openai.AsyncOpenAI(
#    1091         **client_params,
#    1092         **async_specific,  # type: ignore[arg-type]
#    1093     )
#    1094     self.async_client = self.root_async_client.chat.completions
#    1095 return self
#
# File ~/aicourse/venv/lib/python3.12/site-packages/openai/_client.py:514, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     512     api_key = os.environ.get("OPENAI_API_KEY")
#     513 if api_key is None:
# --> 514     raise OpenAIError(
#     515         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     516     )
#     517 if callable(api_key):
#     518     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
from langchain_community.llms import FakeListLLM

# Create a fake LLM that always returns the same responses
fake_llm = FakeListLLM(responses=["Hello"])

result = fake_llm.invoke("Any input will return Hello")
print(result)  # Output: Hello
# Out:
# Hello

# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import SystemMessage, HumanMessage
chat = ChatAnthropic(model="claude-sonnet-4-6")
messages = [
    SystemMessage(content="You're a helpful programming assistant"),
    HumanMessage(content="Write a Python function to calculate factorial")
    ]
response = chat.invoke(messages)
print(response.content)
# Out:
# ## Factorial Function in Python
#
# Here are a few different approaches to calculate factorial:
#
# ### 1. Recursive Approach
# ```python
# def factorial_recursive(n):
#     """
#     Calculate factorial using recursion.
#
#     Args:
#         n (int): Non-negative integer
#
#     Returns:
#         int: Factorial of n
#
#     Raises:
#         ValueError: If n is negative
#         TypeError: If n is not an integer
#     """
#     if not isinstance(n, int):
#         raise TypeError("Input must be an integer")
#     if n < 0:
#         raise ValueError("Factorial is not defined for negative numbers")
#
#     # Base case
#     if n == 0 or n == 1:
#         return 1
#
#     # Recursive case
#     return n * factorial_recursive(n - 1)
# ```
#
# ### 2. Iterative Approach
# ```python
# def factorial_iterative(n):
#     """
#     Calculate factorial using iteration.
#
#     Args:
#         n (int): Non-negative integer
#
#     Returns:
#         int: Factorial of n
#     """
#     if not isinstance(n, int):
#         raise TypeError("Input must be an integer")
#     if n < 0:
#         raise ValueError("Factorial is not defined for negative numbers")
#
#     result = 1
#     for i in range(2, n + 1):
#         result *= i
#
#     return result
# ```
#
# ### 3. Using `math` Module (Built-in)
# ```python
# import math
#
# def factorial_builtin(n):
#     """Calculate factorial using Python's built-in math module."""
#     if n < 0:
#         raise ValueError("Factorial is not defined for negative numbers")
#     return math.factorial(n)
# ```
#
# ### Example Usage
# ```python
# # Test all approaches
# for func in [factorial_recursive, factorial_iterative, factorial_builtin]:
#     print(f"{func.__name__}:")
#     print(f"  0! = {func(0)}")
#     print(f"  1! = {func(1)}")
#     print(f"  5! = {func(5)}")
#     print(f" 10! = {func(10)}")
# ```
#
# ### Output
# ```
# factorial_recursive:
#   0! = 1
#   1! = 1
#   5! = 120
#  10! = 3628800
# ```
#
# ## Comparison
#
# | Approach | Pros | Cons |
# |----------|------|------|
# | **Recursive** | Clean & readable | Stack overflow risk for large `n` |
# | **Iterative** | Memory efficient | Slightly more verbose |
# | **Built-in** | Fastest & reliable | Requires `math` module |
#
# > **Recommendation:** Use `math.factorial()` for production code, as it's optimized and handles edge cases automatically.

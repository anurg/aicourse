# %% [markdown]
# - Knowledge Graph is  a database that stores information in nodes and relationships.
# - both nodes and relationships can have properties
# - nodes can be given labels to group them together
# -

# %%
cypher="""match (n)
return count(n)"""

# %%
result=kg.query(cypher)
result

# %%
cypher="""match (n)
return count(n) AS numberOfNodes"""
result=kg.query(cypher)

# %%
https://www.puppygraph.com/blog/cypher-programming-language

# %%
pip install langchain-neo4j neo4j python-dotenv langchain-community
# Out:
# Collecting langchain-neo4j
#   Downloading langchain_neo4j-0.9.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting neo4j
#   Downloading neo4j-6.2.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: langchain-community in ./.venv/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langchain-neo4j) (1.0.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langchain-neo4j) (1.2.18)
# Requirement already satisfied: langgraph<2.0.0,>=1.0.2 in ./.venv/lib/python3.12/site-packages (from langchain-neo4j) (1.1.1)
# Collecting neo4j-graphrag<2.0.0,>=1.12.0 (from langchain-neo4j)
#   Downloading neo4j_graphrag-1.16.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pytz in ./.venv/lib/python3.12/site-packages (from neo4j) (2025.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.12/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.7.16)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in ./.venv/lib/python3.12/site-packages (from langchain-community) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./.venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.12/site-packages (from langgraph<2.0.0,>=1.0.2->langchain-neo4j) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.12/site-packages (from langgraph<2.0.0,>=1.0.2->langchain-neo4j) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from langgraph<2.0.0,>=1.0.2->langchain-neo4j) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in ./.venv/lib/python3.12/site-packages (from langgraph<2.0.0,>=1.0.2->langchain-neo4j) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Collecting fsspec>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting json-repair<1.0.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading json_repair-0.59.5-py3-none-any.whl.metadata (19 kB)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading pypdf-6.10.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting scipy<2.0.0,>=1.13.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.2 MB/s eta 0:00:00
# Collecting types-pyyaml<7.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading types_pyyaml-6.0.12.20260508-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-neo4j) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<2.0.0,>=1.0.2->langchain-neo4j) (1.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-neo4j) (2.41.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Downloading langchain_neo4j-0.9.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.5 MB/s eta 0:00:00
# Downloading neo4j-6.2.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 11.3 MB/s eta 0:00:00
# Downloading neo4j_graphrag-1.16.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.4/256.4 kB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 2.0 MB/s eta 0:00:00 MB/s eta 0:00:01m
# Downloading json_repair-0.59.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.1 MB/s eta 0:00:00
# Downloading pypdf-6.10.2-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 9.2 MB/s eta 0:00:0016.5 MB/s eta 0:00:01
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 5.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading types_pyyaml-6.0.12.20260508-py3-none-any.whl (20 kB)
# Installing collected packages: types-pyyaml, scipy, pypdf, neo4j, json-repair, fsspec, neo4j-graphrag, langchain-neo4j
# Successfully installed fsspec-2026.4.0 json-repair-0.59.5 langchain-neo4j-0.9.0 neo4j-6.2.0 neo4j-graphrag-1.16.0 pypdf-6.10.2 scipy-1.17.1 types-pyyaml-6.0.12.20260508
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain_neo4j import Neo4jGraph

# %%
NEO4J_URI= "bolt://127.0.0.1:7687"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="neo4jneo4j"

# %%
kg = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database="neo4j"
)

# Optional: Verify the connection and refresh the schema
kg.refresh_schema()
print("Connection established and schema refreshed.")
# Out:
# Connection established and schema refreshed.

# %%
query1 = """
        CREATE (p1:Person {name: 'Alice Johnson', age: 28, city: 'New York'})
        CREATE (p2:Person {name: 'Bob Smith', age: 35, city: 'San Francisco'})
        CREATE (p3:Person {name: 'Carol White', age: 42, city: 'Boston'})
        CREATE (p4:Person {name: 'David Brown', age: 31, city: 'Seattle'})
        RETURN 'Created 4 Person nodes' AS result
        """

# %%
result =kg.query(query1)
print("\nQuery executed:")
print(query1)
print("\nResult:", result)
# Out:
# Query executed:
#
#         CREATE (p1:Person {name: 'Alice Johnson', age: 28, city: 'New York'})
#         CREATE (p2:Person {name: 'Bob Smith', age: 35, city: 'San Francisco'})
#         CREATE (p3:Person {name: 'Carol White', age: 42, city: 'Boston'})
#         CREATE (p4:Person {name: 'David Brown', age: 31, city: 'Seattle'})
#         RETURN 'Created 4 Person nodes' AS result
#
#
# Result: [{'result': 'Created 4 Person nodes'}]

# %%
query2 = """CREATE (c1:Company:TechCompany {
            name: 'TechCorp', 
            founded: 2010, 
            industry: 'Software',
            employees: 500
        })
        CREATE (c2:Company:TechCompany {
            name: 'DataSolutions', 
            founded: 2015, 
            industry: 'Data Analytics',
            employees: 150
        })
        RETURN 'Created 2 Company nodes with multiple labels' AS result
        """

# %%
result =kg.query(query2)
print("\nQuery executed:")
print(query2)
print("\nResult:", result)
# Out:
# Query executed:
# CREATE (c1:Company:TechCompany {
#             name: 'TechCorp',
#             founded: 2010,
#             industry: 'Software',
#             employees: 500
#         })
#         CREATE (c2:Company:TechCompany {
#             name: 'DataSolutions',
#             founded: 2015,
#             industry: 'Data Analytics',
#             employees: 150
#         })
#         RETURN 'Created 2 Company nodes with multiple labels' AS result
#
#
# Result: [{'result': 'Created 2 Company nodes with multiple labels'}]

# %%
query3 = """
        MATCH (p:Person {name: 'Alice Johnson'}), (c:Company {name: 'TechCorp'})
        CREATE (p)-[r:WORKS_AT {since: 2020, position: 'Software Engineer'}]->(c)
        RETURN p.name + ' works at ' + c.name AS result
        """
####(Alice Johnson) -[:WORKS_AT {since: 2020, position: 'Software Engineer'}]-> (TechCorp)

# %%
result =kg.query(query3)
print("\nQuery executed:")
print(query3)
print("\nResult:", result)
# Out:
# Query executed:
#
#         MATCH (p:Person {name: 'Alice Johnson'}), (c:Company {name: 'TechCorp'})
#         CREATE (p)-[r:WORKS_AT {since: 2020, position: 'Software Engineer'}]->(c)
#         RETURN p.name + ' works at ' + c.name AS result
#
#
# Result: [{'result': 'Alice Johnson works at TechCorp'}, {'result': 'Alice Johnson works at TechCorp'}, {'result': 'Alice Johnson works at TechCorp'}]

# %%
query4 = """
        MATCH (p1:Person {name: 'Bob Smith'}), (c:Company {name: 'DataSolutions'})
        CREATE (p1)-[:WORKS_AT {since: 2019, position: 'Data Scientist'}]->(c)
        
        WITH p1
        MATCH (p2:Person {name: 'Alice Johnson'})
        CREATE (p1)-[:KNOWS {since: 2018, relationship: 'Friends'}]->(p2)
        
        RETURN 'Created multiple relationships' AS result
        """

####(Bob Smith) -[:WORKS_AT {since:2019, position:'Data Scientist'}]-> (DataSolutions)
###(Bob Smith) -[:KNOWS {since:2018, relationship:'Friends'}]-> (Alice Johnson)

# %%
result =kg.query(query4)
print("\nQuery executed:")
print(query4)
print("\nResult:", result)
# Out:
# Query executed:
#
#         MATCH (p1:Person {name: 'Bob Smith'}), (c:Company {name: 'DataSolutions'})
#         CREATE (p1)-[:WORKS_AT {since: 2019, position: 'Data Scientist'}]->(c)
#
#         WITH p1
#         MATCH (p2:Person {name: 'Alice Johnson'})
#         CREATE (p1)-[:KNOWS {since: 2018, relationship: 'Friends'}]->(p2)
#
#         RETURN 'Created multiple relationships' AS result
#
#
# Result: [{'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}, {'result': 'Created multiple relationships'}]

# %%
query5 = """
        MERGE (p:Person {name: 'Alice Johnson'})
        ON CREATE SET p.created = timestamp()
        ON MATCH SET p.lastSeen = timestamp()
        RETURN p.name, p.created, p.lastSeen
        """

# %%
#Selecting All Nodes of a Type
       # Basic SELECT
query = """
        MATCH (p:Person)
        RETURN p.name AS name, p.age AS age, p.city AS city
        ORDER BY p.age
        """

# %%
# Simple WHERE clause
query = """
        MATCH (p:Person)
        WHERE p.age > 30
        RETURN p.name AS name, p.age AS age
        """

# %%
# Multiple conditions
query = """
        MATCH (p:Person)
        WHERE p.age >= 30 AND p.city IN ['New York', 'Boston']
        RETURN p.name AS name, p.age AS age, p.city AS city
        """

# %%
# Query with relationship filtering
query = """
        MATCH (p1:Person)-[k:KNOWS]->(p2:Person)
        WHERE k.since < 2020
        RETURN p1.name AS person1, p2.name AS person2, k.since AS friendsSince
        """

# %%
#aggregation
query = """
        MATCH (p:Person)
        RETURN COUNT(p) AS totalPeople,
               AVG(p.age) AS avgAge,
               MIN(p.age) AS youngest,
               MAX(p.age) AS oldest
        """

# %%
# Group by
query = """
        MATCH (p:Person)
        RETURN p.city AS city, 
               COUNT(p) AS peopleCount,
               AVG(p.age) AS avgAge
        ORDER BY peopleCount DESC
        """

# %%
# Update single property
query = """
        MATCH (p:Person {name: 'Alice Johnson'})
        SET p.age = 29, p.email = 'alice@example.com'
        RETURN p.name AS name, p.age AS age, p.email AS email
        """

# %%
 ######Querying Relationships
        ########Find nodes connected by relationships
        """query = """
        MATCH (p:Person)-[r:WORKS_AT]->(c:Company)
        RETURN p.name AS employee, 
               r.position AS position, 
               c.name AS company,
               r.since AS startYear
        """

# %%
result =kg.query(query2)
print("\nQuery executed:")
print(query2)
print("\nResult:", result)
# Out:
# Query executed:
# CREATE (c1:Company:TechCompany {
#             name: 'TechCorp',
#             founded: 2010,
#             industry: 'Software',
#             employees: 500
#         })
#         CREATE (c2:Company:TechCompany {
#             name: 'DataSolutions',
#             founded: 2015,
#             industry: 'Data Analytics',
#             employees: 150
#         })
#         RETURN 'Created 2 Company nodes with multiple labels' AS result
#
#
# Result: [{'result': 'Created 2 Company nodes with multiple labels'}]
